# %% [markdown]
# # 05 — Statistical Analysis
#
# Structured analysis of the master dataset.
#
# Sections (adapt to your project):
# 1. **Group differences** — ANOVA / Kruskal-Wallis + post-hoc tests
# 2. **What drives the outcome?** — Multiple regression (OLS)
# 3. **Policy/treatment effects** — With confounders controlled
# 4. **Typology** — Clustering into archetypes
# 5. **Residual analysis** — Which observations are outliers given the model?

# %%
import sys, os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

PROJECT = Path.cwd()
while not (PROJECT / 'config.yaml').exists() and PROJECT != PROJECT.parent:
    PROJECT = PROJECT.parent
os.chdir(PROJECT)
sys.path.insert(0, str(PROJECT))

# Always read from the EXPORT (not raw DuckDB tables) to ensure
# analysis is consistent with published/packaged data.
# df = pd.read_parquet(PROJECT / 'export' / 'my_dataset_v1.parquet')
# print(f'{len(df)} rows x {len(df.columns)} cols')

# %% [markdown]
# ---
# ## 1. Group Differences
#
# Are the groupings (region, category, policy) statistically significant?

# %%
# TODO: Kruskal-Wallis + Tukey HSD for your key groupings
pass

# %% [markdown]
# ---
# ## 2. What Drives the Outcome?
#
# OLS regression: which factors correlate with your outcome variable?

# %%
# TODO: Define outcome + predictors, standardize, fit OLS, check VIF
pass

# %% [markdown]
# ---
# ## 3. Policy/Treatment Effects (with confounders)
#
# Isolate individual policy variables while controlling for structural factors.

# %%
# TODO: smf.ols formulas with C(group) confounders
pass

# %% [markdown]
# ---
# ## 4. Typology (Clustering)
#
# Group observations into archetypes for narrative and social content.

# %%
# TODO: KMeans with elbow plot, profile clusters, name them
pass

# %% [markdown]
# ---
# ## 5. Residual Analysis
#
# Which observations are better/worse than the model predicts?

# %%
# TODO: Fit simple regression, extract residuals, rank outliers
pass
